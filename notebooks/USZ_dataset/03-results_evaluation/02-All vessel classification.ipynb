# %% [markdown]
# # Validate peroformance of the vessel tree

# %% [markdown]
# ## Dice-Score

# %% [markdown]
# ## Hausdorff distance

# %% [markdown]
# ## Recall

# %% [markdown]
# ## Precision

# %% [markdown]
# # Validate that the vessel tree includes the aneurysms well

# %% [markdown]
# ## What is the recall of aneurysms in the vessel tree?

# %% [markdown]
# ## Dilate the aneurysm mask and calculate the precision

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sd_usz_td_usz.csv')
df
# Out:
#      vol_name  dice_aneur_kostas  recall_aneur_kostas  precision_aneur_kostas  \
# 0    0.nii.gz           0.894966             0.809899                       1
# 1    1.nii.gz           0.865342             0.762646                       1
# 2   18.nii.gz           0.992763             0.985631                       1
# 3   19.nii.gz           0.981017             0.962741                       1
# 4   25.nii.gz           0.958287             0.919915                       1
# 5   27.nii.gz           1.000000             1.000000                       1
# 6    3.nii.gz           0.966823             0.935776                       1
# 7   31.nii.gz           0.962907             0.928467                       1
# 8   48.nii.gz           0.995789             0.991613                       1
# 9   49.nii.gz           0.925006             0.860475                       1
# 10  51.nii.gz           0.923935             0.858623                       1
# ...

# %%
df.plot.scatter(x='Diameter', y='dice_tm_aneurysm_only')
# Insert a vertical dashed line at x=3, and x=4
plt.axvline(x=3, color='red', linestyle='--', alpha=0.6)
plt.axvline(x=4, color='red', linestyle='--', alpha=0.6)
plt.title('Dice score per volume vs approximate diameter')
plt.show()
